# %%
### from random import randint 

#initialize board 
board = []

for x in range(1,6):
    y = board.append(["💦"] * 5)

    
def print_board(board):
    for r in board:
        print " ".join(r)
        
#print the board
print "WELCOME TO BATTLESHIP\n"       
print_board(board)

#define the ship placement


def random_col():
    return randint(0, len(board[0]) - 1)       

def random_row():
    return randint(0, len(board) - 1)

opponent_row = random_row()
opponent_col = random_col()


#ask for turn

for t in range(0,7):
    player_guess_col = int(raw_input("Please enter a column number (0-4): "))
    player_guess_row = int(raw_input("Please enter a row number (0-4): "))
    
    if player_guess_row == opponent_row and player_guess_col == opponent_col:
        print ("Congratulations! You have hit your opponent's ship! 🎉🎊🎉🎇🎉")
        break
    else:
        if (player_guess_row > 5 or player_guess_row < 0) or (player_guess_col > 5 or player_guess_col < 0):
            print ("That's not even in the ocean!")
                       
        elif ((player_guess_row != opponent_row) or (player_guess_col != opponent_col)):
            print ("That's a miss!")
            board[player_guess_row][player_guess_col] = "💣"
            
        elif (board[player_guess_row][player_guess_col] == "💣"):
            print ("You already guessed that!")

        else:
            print ("That's not a number!")
            continue
              
        
    if (t == 6):
        print 'You have run out of turns. GAME OVER'
        break
     
    else: print_board(board)
# Out:
# WELCOME TO BATTLESHIP
#
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# Please enter a column number (0-4): 4
# Please enter a row number (0-4): 3
# That's a miss!
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💣
# 💦 💦 💦 💦 💦
# Please enter a column number (0-4): 2
# Please enter a row number (0-4): 3
# That's a miss!
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💣 💦 💣
# 💦 💦 💦 💦 💦
# Please enter a column number (0-4): 1
# Please enter a row number (0-4): 1
# That's a miss!
# 💦 💦 💦 💦 💦
# 💦 💣 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💣 💦 💣
# 💦 💦 💦 💦 💦
# Please enter a column number (0-4): 2
# Please enter a row number (0-4): 3
# That's a miss!
# 💦 💦 💦 💦 💦
# 💦 💣 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💣 💦 💣
# 💦 💦 💦 💦 💦
# Please enter a column number (0-4): 4
# Please enter a row number (0-4): 3
# That's a miss!
# 💦 💦 💦 💦 💦
# 💦 💣 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💣 💦 💣
# 💦 💦 💦 💦 💦
# Please enter a column number (0-4): 4
# Please enter a row number (0-4): 3
# That's a miss!
# 💦 💦 💦 💦 💦
# 💦 💣 💦 💦 💦
# 💦 💦 💦 💦 💦
# 💦 💦 💣 💦 💣
# ...

# %% [markdown]
# ### 2
# 2##
